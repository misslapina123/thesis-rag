# %%
import pandas as pd

# %%
path = f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_summarize.csv"

# %%
df = pd.read_csv(path)
df
# Out:
#     Unnamed: 0                                    System  Faithfulness  \
# 0            0                                   GPT-3.5      1.000000
# 1            1                                     GPT-4      0.971429
# 2            2                                     Naive      0.686914
# 3            3                                 Recursive      0.669849
# 4            4                     Chunk 500, overlap 0%      0.953704
# 5            5                     Chunk 500, overlap 5%      0.944444
# 6            6                    Chunk 500, overlap 10%      0.705793
# 7            7                    Chunk 500, overlap 15%      0.752637
# 8            8                    Chunk 500, overlap 20%      0.984127
# 9            9                    Chunk 1000, overlap 0%      1.000000
# 10          10                    Chunk 1000, overlap 5%      0.877500
# 11          11                   Chunk 1000, overlap 10%      0.875000
# ...

# %%
df_round = round(df, 3)
df_round
# Out:
#     Unnamed: 0                                    System  Faithfulness  \
# 0            0                                   GPT-3.5         1.000
# 1            1                                     GPT-4         0.971
# 2            2                                     Naive         0.687
# 3            3                                 Recursive         0.670
# 4            4                     Chunk 500, overlap 0%         0.954
# 5            5                     Chunk 500, overlap 5%         0.944
# 6            6                    Chunk 500, overlap 10%         0.706
# 7            7                    Chunk 500, overlap 15%         0.753
# 8            8                    Chunk 500, overlap 20%         0.984
# 9            9                    Chunk 1000, overlap 0%         1.000
# 10          10                    Chunk 1000, overlap 5%         0.878
# 11          11                   Chunk 1000, overlap 10%         0.875
# ...

# %%
df_round.to_csv(path, index = False)
