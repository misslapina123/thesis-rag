# %%
import pandas as pd

# %%
dataframes = [
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_qa.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_reporting.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_summarize.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_errors.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_errors.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_qa_news.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_reporting.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_summary.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_errors.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_qa.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_report.csv"),
    pd.read_csv(f"C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_summarize.csv")
]

# %%
best_systems_3 = pd.DataFrame()

# Iterate through each dataframe
for df in dataframes:
    best = df.nlargest(3,"Average")
    best_systems_3 = best_systems_3.append(best)

best_systems_3
# Out:
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\2302803501.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_3 = best_systems_3.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\2302803501.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_3 = best_systems_3.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\2302803501.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_3 = best_systems_3.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\2302803501.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
system_counts = best_systems_3["System"].value_counts()
system_counts
# Out:
# Chunk 1000, overlap 0%, GPT-4                3
# Chunk 1000, overlap 10%                      2
# Search query                                 2
# Ensambler 3, GPT-4                           2
# Ensambler 3                                  2
# Chunk size 1000, overlap 5%, K=5             1
# GPT-4                                        1
# Ensambler 2, GPT-4                           1
# MMR GPT4                                     1
# Ensambler 2                                  1
# Chunk size 500, overlap 0%, K=6              1
# Chunk 500, overlap 0%                        1
# Chunk 1000, overlap 0%                       1
# Naive retriever, GPT-4                       1
# Naive                                        1
# Chunk 1000, overlap 5%                       1
# Chunk 1000, overlap 20%                      1
# Chunk 1000, overlap 15%                      1
# Parent Retriever 1000-200                    1
# Parent Retriever 1500-200                    1
# ...

# %%
# Best 1
best_systems = pd.DataFrame()

# Iterate through each dataframe
for df in dataframes:
    best = df.nlargest(1,"Average")
    best_systems = best_systems.append(best)

system_counts = best_systems["System"].value_counts()
system_counts
# Out:
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\749534732.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems = best_systems.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\749534732.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems = best_systems.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\749534732.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems = best_systems.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_24908\749534732.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems = best_systems.append(best)
# ...

# %%
import pandas as pd

dataframes = [
    {"path": "thesis-rag/papers/results/results_qa.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_qa.csv")},
    {"path": "thesis-rag/papers/results/results_reporting.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_reporting.csv")},
    {"path": "thesis-rag/papers/results/results_summarize.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_summarize.csv")},
    {"path": "thesis-rag/papers/results/results_errors.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_errors.csv")},
    {"path": "thesis-rag/news/results/results_errors.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_errors.csv")},
    {"path": "thesis-rag/news/results/results_qa_news.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_qa_news.csv")},
    {"path": "thesis-rag/news/results/results_reporting.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_reporting.csv")},
    {"path": "thesis-rag/news/results/results_summary.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_summary.csv")},
    {"path": "thesis-rag/ballad/results/results_errors.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_errors.csv")},
    {"path": "thesis-rag/ballad/results/results_qa.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_qa.csv")},
    {"path": "thesis-rag/ballad/results/results_report.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_report.csv")},
    {"path": "thesis-rag/ballad/results/results_summarize.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_summarize.csv")}
]

best_systems_1 = pd.DataFrame()

# Iterate through each dataframe
for df_info in dataframes:
    df_path = df_info["path"]
    df_data = df_info["data"]
    df_data["File_Path"] = df_path
    best = df_data.nlargest(1,"Context Precision")
    best_systems_1 = best_systems_1.append(best)

best_systems_1.reset_index(drop=True, inplace=True)

best_systems_1
# Out:
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\4027635493.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_1 = best_systems_1.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\4027635493.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_1 = best_systems_1.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\4027635493.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_1 = best_systems_1.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\4027635493.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
system_counts = best_systems_1["System"].value_counts()
system_counts
# Out:
# Chunk 1000, overlap 5%                      2
# Chunk size 1000, overlap 10%, K=2           1
# Naive                                       1
# Chunk size 2000, overlap 10%, K=3, GPT-4    1
# Ensambler 1                                 1
# Parent Retriever 1500-200                   1
# Chunk size 3000, overlap 20%, K=2           1
# Chunk size 500, overlap 0%, K=6             1
# Chunk size 2000, 20%, K=6                   1
# Ensambler 3                                 1
# Chunk 3000, overlap 20%                     1
# Name: System, dtype: int64

# %%
dataframes = [
    {"path": "thesis-rag/papers/results/results_qa.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_qa.csv")},
    {"path": "thesis-rag/papers/results/results_reporting.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_reporting.csv")},
    {"path": "thesis-rag/papers/results/results_summarize.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_summarize.csv")},
    {"path": "thesis-rag/papers/results/results_errors.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/papers/results/results_errors.csv")},
    {"path": "thesis-rag/news/results/results_errors.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_errors.csv")},
    {"path": "thesis-rag/news/results/results_qa_news.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_qa_news.csv")},
    {"path": "thesis-rag/news/results/results_reporting.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_reporting.csv")},
    {"path": "thesis-rag/news/results/results_summary.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/news/results/results_summary.csv")},
    {"path": "thesis-rag/ballad/results/results_errors.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_errors.csv")},
    {"path": "thesis-rag/ballad/results/results_qa.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_qa.csv")},
    {"path": "thesis-rag/ballad/results/results_report.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_report.csv")},
    {"path": "thesis-rag/ballad/results/results_summarize.csv",
     "data": pd.read_csv("C:/Users/sigit/OneDrive/TSI/thesis/thesis-rag/ballad/results/results_summarize.csv")}
]

best_systems_recall = pd.DataFrame()

# Iterate through each dataframe
for df_info in dataframes:
    df_path = df_info["path"]
    df_data = df_info["data"]
    df_data["File_Path"] = df_path
    best = df_data.nlargest(1,"Context Recall")
    best_systems_recall = best_systems_recall.append(best)

best_systems_recall.reset_index(drop=True, inplace=True)

best_systems_recall
# Out:
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\3001444633.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_recall = best_systems_recall.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\3001444633.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_recall = best_systems_recall.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\3001444633.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   best_systems_recall = best_systems_recall.append(best)
# C:\Users\sigit\AppData\Local\Temp\ipykernel_17928\3001444633.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
system_counts = best_systems_recall["System"].value_counts()
system_counts
# Out:
# Chunk 500, overlap 5%                1
# Chunk 500, overlap 0%                1
# Chunk size 2000, overlap 10%, K=3    1
# Naive                                1
# Parent Retriever 1500-200            1
# Chunk size 3000, overlap 20%, K=2    1
# Ensambler 1                          1
# Chunk 2000, overlap 0%               1
# BM25                                 1
# Chunk 500, overlap 15%               1
# Chunk size 500, overlap 15%, K=5     1
# Search query                         1
# Name: System, dtype: int64
